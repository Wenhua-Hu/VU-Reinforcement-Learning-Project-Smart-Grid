# %%
! pip install gym
# ! pip install pygame
# ! pip install mockseries --user
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /root/.local/lib/python3.10/site-packages (from gym) (1.24.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)

# %%
import torch
from gym import Env
from gym.spaces import Discrete, Box, MultiDiscrete
import numpy as np
import random
import os
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Mounted at /content/drive

# %%
df_train_data = pd.read_excel('train.xlsx', index_col=0)
df_train_data = df_train_data.reset_index(drop=True)
# train_data = df_train_data.drop(columns=['PRICES'])
# train_data.columns = [i for i in range(24)]
# train_data = train_data.dropna()
# price_quantiles = np.quantile(train_data, [0.25, 0.5, 0.75])

# c = pd.cut(
#     train_data.stack(),
#     [-np.inf] + list(price_quantiles) + [np.inf],
#     labels=[0, 1, 2, 3]
# )
# prices = train_data.join(c.unstack().add_suffix('_cat'))
# episodic_prices = price_discretized.iloc[:, 24:].copy()
# prices = price_discretized.iloc[:, :24].copy()

# %%
df_train_data
# Out:
#       Hour 01  Hour 02  Hour 03  Hour 04  Hour 05  Hour 06  Hour 07  Hour 08  \
# 0       24.31    24.31    21.71     8.42     0.01     0.01     0.02     0.01
# 1       16.01    11.00     9.01     7.50     9.00     7.45    16.50    28.01
# 2       28.00    24.50    24.15    18.99    15.50    23.11    29.01    39.73
# 3       31.01    28.69    27.00    24.20    12.02    27.00    28.00    34.85
# 4       22.00    19.50    17.55    15.91    11.40    22.65    27.30    34.00
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1091    27.99    21.00    14.00     5.00     0.01     0.01     0.01     0.01
# 1092    19.04    20.55    20.00    11.94     9.99    13.31    18.31    29.52
# 1093    28.50    25.55    22.86    17.00    16.58    19.78    26.91    33.90
# 1094    21.21    16.73    12.66     9.50     9.04     9.78    16.30    24.36
# 1095    17.63    12.15    10.21     8.89     8.36     9.82    11.65    22.14
#
#       Hour 09  Hour 10  ...  Hour 15  Hour 16  Hour 17  Hour 18  Hour 19  \
# 0        0.01     6.31  ...    15.00    10.00     8.17    27.77    37.99
# 1       29.96    39.60  ...    37.57    36.45    37.99    53.00    59.69
# 2       43.81    49.09  ...    43.21    43.99    48.00    57.00    60.99
# 3       41.31    42.03  ...    40.01    38.00    42.66    53.00    58.99
# 4       40.01    45.00  ...    40.06    38.00    38.61    49.84    53.00
# ...       ...      ...  ...      ...      ...      ...      ...      ...
# 1091     0.01    18.00  ...    25.00    19.11    17.69    34.99    44.43
# 1092    35.77    41.00  ...    38.03    37.00    39.63    55.29    56.18
# 1093    34.89    37.10  ...    34.87    29.01    28.41    42.30    47.45
# 1094    34.00    38.01  ...    38.41    32.00    33.37    44.99    48.00
# 1095    30.00    34.00  ...    33.00    29.82    30.28    40.00    40.48
#
#       Hour 20  Hour 21  Hour 22  Hour 23  Hour 24
# 0       33.11    37.99    33.00    36.48    30.65
# 1       50.09    50.00    36.22    31.09    29.84
# 2       55.51    51.77    34.51    39.31    38.05
# 3       53.50    44.01    35.00    34.46    31.57
# 4       45.91    36.74    29.61    30.61    27.51
# ...       ...      ...      ...      ...      ...
# 1091    44.50    44.00    36.32    39.93    32.00
# 1092    45.88    41.30    36.44    38.20    34.00
# 1093    43.62    38.62    31.27    35.00    30.08
# 1094    42.00    34.01    28.18    33.00    27.99
# 1095    36.00    29.00    24.82    31.28    31.00
#
# [1096 rows x 24 columns]

# %%
# fix something here maybe in order to have it so that action is adjusted in step function to closest action that is allowed at 7am,
# and so that the action does not result in negative battery level

def get_legal_actions_at_last(all_actions, current_level, min_level=2):
    '''
    Expected behavior: [-2,-1,0,1,2], currently 0 -> [2]
    Expected behavior: [-2,-1,0,1,2], currently 1 -> [1,2]
    Expected behavior: [-2,-1,0,1,2], currently 2 -> [0,1,2]
    Expected behavior: [-2,-1,0,1,2], currently 3 -> [-1,0,1,2]
    Expected behavior: [-2,-1,0,1,2], currently 4 -> [-2,-1,0,1,2]
    '''
    all_actions = np.asarray(all_actions)
    charge_needed = min_level - current_level
    avail_actions = all_actions[np.where(all_actions >= charge_needed)]
    # avail_actions = all_actions[list(np.where(all_actions >= charge_needed)[0])]
    return avail_actions.tolist()

def get_legal_actions(all_actions, current_level, min_level=0):
    all_actions = np.asarray(all_actions)
    underlying_levels = all_actions + current_level
    # avail_actions = all_actions[list(np.where(underlying_levels >= 0)[0])]
    avail_actions = all_actions[np.where(underlying_levels >= min_level)]
    return avail_actions.tolist()

# %%
len(df_train_data.iloc[:, 1:25].to_numpy().flatten())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 25208

# %%
# 1 make the step function go through one hour at a time, and through the entire dataframe (sequentially) in total *
# 2 take at_home out of the state *
# 3 include the action mechanics inside of the step function *
# 4 test environment again on random policy loop *
# 5 try q learning
# 6 change action to -1, 1 range
# 7 change reward calculation *
# 8 test with the test environment (validate using main.py)
# 9 include electricity price, and maybe more time elements in the state representation (week/month/year)
# 10 change hour from 08-07 to 01-00

#
# action comes in in continuous form, is modified in the step function in continuous form within range [-1,1], which
# is used then to update state variables, i.e. battery level, into a continuous variable between [0,50]
# state is returned in continuous form
# in tabular Q learning, state (from env.step) is taken and discretized to get next action
# in approximator methods, state is taken as continuous and used to get next action

class StorageEnv(Env):
    def __init__(self, path_to_train_data):
        '''
        Initialization of the energy storage environment;
        We interpret a run through all historical price data as one trajectory = one episode,
        where for each hour of each day, we can run the step function to update from one state
        to the next, given some action for that hour (the step function will return the next
        state, as well as next reward, and whether the entire historical dataset has been
        iterated through using the 'done' variable in the return statement).
        '''

        self.train_data = pd.read_excel(path_to_train_data)
        self.price_values = self.train_data.iloc[:, 1:25].to_numpy()
        self.timestamps = self.train_data['PRICES']
        self.nr_hours = self.price_values.shape[0]*self.price_values.shape[1] # number of hours in the dataset in total = 25208 for train.xlsx


        self.values_actions =  [-20, -10, 0, 10, 20]
        self.batteries =  [0, 10, 20, 30, 40, 50]
        self.action_repr = [-2,-1,0,1,2]

        self.done = False # indicates whether trajectory (run through entire dataset) has finished, analogous to 'terminated' argument

        self.action_space = Discrete(5, start=-2)
        self.battery_space = Discrete(6, start=0)
        self.position_space = Discrete(2, start=0)

        self.counter = 0
        self.hour = 1
        self.day = 1
        self.num_hours_day = 24

        self.min_battery_level_start = 20
        self.min_battery_level = 0
        self.max_battery_level = 50
        self.max_charging_level = 25

        # battery level from 0 to 50 (10 incr.), indication car at home or not
        self.observation_space = MultiDiscrete([self.battery_space.n,
                                                self.position_space.n,
                                                self.num_hours_day])

        # initialize state vars
        self.battery_level = np.random.randint(self.min_battery_level_start, self.max_battery_level)
        # randomly initialize athome with 50/50 chance of being away at hour 0 (8am) or not
        self.at_home = np.random.randint(self.position_space.n) # dont need this anymore or?
        # initial state
        self.state = [self.battery_level, self.hour]


    def step(self, action):
        ######### at current timestep t
        ### battery comsumption at timestep t

        # no charging/discharging if car is away, besides reduction of batter level by 20kwh at 8am (enforced later on)
        if not self.at_home: # check if car is currently away, enforced by overriding previous if statement
          action = 0

        # meeting constraints of having 20kwh at 7am, and alwys more than 0kwh stored
        elif self.at_home:
          # calculate the exact action you need to get the battery to 20kwh, by taking the min of all sufficient (=legal) actions
          if hour == 7:
            legal_actions = get_legal_actions_at_last(self.action_repr, self.battery_level)
            if action not in legal_actions: # check if action chosen by agent ensures 20kwh of battery at 7am
              action = min(legal_actions)
          # rest of the day, ensure that battery stays above 0kwh
          else:
            legal_actions = get_legal_actions(self.action_repr, self.battery_level)
            if action not in legal_actions:
              action = min(legal_actions)

        # removing 20kwh from battery when going away from home
        if not self.at_home:
          self.battery_level = self.battery_level-2 if self.hour == 0 else self.battery_level

        # update battery level based on the picked acion at timestep t
        if self.at_home:
            self.battery_level += action

        # no over-charging above 50kwh
        if self.battery_level >= 5:
            self.battery_level = 5

        # should we move the constraints not lower 0 here ??

        ######### update the state for next hour, timestep t+1
        # keep the hour 8 ~ 18 same, otherwise athome = True
        self.at_home = self.at_home if self.hour < 18 else 1

        # reward calculations
        hourly_price = self.price_values[self.day-1][self.hour-1]
        cost_factor = 1.0 if action < 0 else 2.0
        efficiency_price_factor = 0.9 if action < 0 else 1.0 # obtained electricity is impacted by 0.9 when selling

        # get amount of kwh bought during this step
        kwhs_charged = action * 10 # change this 10 when changing action space!!!
        price_of_charging = kwhs_charged * cost_factor * efficiency_price_factor * (hourly_price/1000) # go from MWh to KWh, multiply by 2 if we are buying
        # add reward here, based on price from table

        reward = (-1.) * price_of_charging # reward for this step, positive if selling, negative when buying

        # update counter and time variables
        self.counter += 1 # update continuous counter (running from 0 - len(df)*24)
        self.hour += 1 # increment hour (running from 1-24 and back to 1 after the day passed)

        if self.counter % 24 == 0: # check if day is over, meaning that it is midnight at timestep t+1
            self.hour = 1 # reset hour of the day for next timestep
            self.day += 1 # increment to start of next day

        # update state
        self.state = [self.battery_level, self.hour]

        # check if all hours in the dataset have been seen
        self.done = self.counter+1 == self.nr_hours

        truncated = False
        info = {}

        return self.state, reward, self.done, truncated, info

    def render(self):
        pass

    def reset(self):
      # initialize battery level randomly between 0 and 6, representing the space 0-50kwh
      self.battery_level = np.random.randint(self.min_battery_level_start, self.max_battery_level)
      # randomly initialize athome with 50/50 chance of being away at hour 0 (8am) or not
      self.at_home = np.random.randint(self.position_space.n)
      # hour may not need to be in the state..?
      self.hour = 1
      self.done = False
       # initial state
      self.state = [self.battery_level, self.hour]

      return self.state

# %%
# 1 make the step function go through one hour at a time, and through the entire dataframe (sequentially) in total *
# 2 take at_home out of the state *
# 3 include the action mechanics inside of the step function *
# 4 test environment again on random policy loop *
# 5 try q learning
# 6 change action to -1, 1 range
# 7 change reward calculation *
# 8 test with the test environment (validate using main.py)
# 9 include electricity price, and maybe more time elements in the state representation (week/month/year)
# 10 change hour from 08-07 to 01-00

class StorageEnv(Env):
    def __init__(self, path_to_train_data):
        '''
        Initialization of the energy storage environment;
        We interpret a run through all historical price data as one trajectory = one episode,
        where for each hour of each day, we can run the step function to update from one state
        to the next, given some action for that hour (the step function will return the next
        state, as well as next reward, and whether the entire historical dataset has been
        iterated through using the 'done' variable in the return statement).
        '''

        self.train_data = pd.read_excel(path_to_train_data)
        self.price_values = self.train_data.iloc[:, 1:25].to_numpy()
        self.timestamps = self.train_data['PRICES']
        self.nr_hours = self.price_values.shape[0]*self.price_values.shape[1] # number of hours in the dataset in total = 25208 for train.xlsx

        self.values_actions =  [-20, -10, 0, 10, 20]
        self.batteries =  [0, 10, 20, 30, 40, 50]
        self.action_repr = [-2,-1,0,1,2]

        self.done = False # indicates whether trajectory (run through entire dataset) has finished, analogous to 'terminated' argument

        self.action_space = Discrete(5, start=-2)
        self.battery_space = Discrete(6, start=0)
        self.position_space = Discrete(2, start=0)

        self.counter = 0
        self.hour = 1
        self.day = 1
        self.num_hours_day = 24

        self.min_battery_level_start = 2
        self.min_battery_level = 0
        self.max_battery_level = 5

        # battery level from 0 to 50 (10 incr.), indication car at home or not
        self.observation_space = MultiDiscrete([self.battery_space.n,
                                                self.position_space.n,
                                                self.num_hours_day])

        # initialize state vars
        self.battery_level = np.random.randint(self.min_battery_level_start, self.max_battery_level)
        # randomly initialize athome with 50/50 chance of being away at hour 0 (8am) or not
        self.at_home = np.random.randint(self.position_space.n) # dont need this anymore or?
        # initial state
        self.state = [self.battery_level, self.hour]


    def step(self, action):
        ######### at current timestep t
        ### battery comsumption at timestep t

        # no charging/discharging if car is away, besides reduction of batter level by 20kwh at 8am (enforced later on)
        if not self.at_home: # check if car is currently away, enforced by overriding previous if statement
          action = 0

        # meeting constraints of having 20kwh at 7am, and alwys more than 0kwh stored
        elif self.at_home:
          # calculate the exact action you need to get the battery to 20kwh, by taking the min of all sufficient (=legal) actions
          if hour == 7:
            legal_actions = get_legal_actions_at_last(self.action_repr, self.battery_level)
            if action not in legal_actions: # check if action chosen by agent ensures 20kwh of battery at 7am
              action = min(legal_actions)
          # rest of the day, ensure that battery stays above 0kwh
          else:
            legal_actions = get_legal_actions(self.action_repr, self.battery_level)
            if action not in legal_actions:
              action = min(legal_actions)

        # removing 20kwh from battery when going away from home
        if not self.at_home:
          self.battery_level = self.battery_level-2 if self.hour == 0 else self.battery_level

        # update battery level based on the picked acion at timestep t
        if self.at_home:
            self.battery_level += action

        # no over-charging above 50kwh
        if self.battery_level >= 5:
            self.battery_level = 5

        # should we move the constraints not lower 0 here ??

        ######### update the state for next hour, timestep t+1
        # keep the hour 8 ~ 18 same, otherwise athome = True
        self.at_home = self.at_home if self.hour < 18 else 1

        # reward calculations
        hourly_price = self.price_values[self.day-1][self.hour-1]
        cost_factor = 1.0 if action < 0 else 2.0
        efficiency_price_factor = 0.9 if action < 0 else 1.0 # obtained electricity is impacted by 0.9 when selling

        # get amount of kwh bought during this step
        kwhs_charged = action * 10 # change this 10 when changing action space!!!
        price_of_charging = kwhs_charged * cost_factor * efficiency_price_factor * (hourly_price/1000) # go from MWh to KWh, multiply by 2 if we are buying
        # add reward here, based on price from table

        reward = (-1.) * price_of_charging # reward for this step, positive if selling, negative when buying

        # update counter and time variables
        self.counter += 1 # update continuous counter (running from 0 - len(df)*24)
        self.hour += 1 # increment hour (running from 1-24 and back to 1 after the day passed)

        if self.counter % 24 == 0: # check if day is over, meaning that it is midnight at timestep t+1
            self.hour = 1 # reset hour of the day for next timestep
            self.day += 1 # increment to start of next day

        # update state
        self.state = [self.battery_level, self.hour]

        # check if all hours in the dataset have been seen
        self.done = self.counter+1 == self.nr_hours

        truncated = False
        info = {}

        return self.state, reward, self.done, truncated, info

    def render(self):
        pass

    def reset(self):
      # initialize battery level randomly between 0 and 6, representing the space 0-50kwh
      self.battery_level = np.random.randint(self.min_battery_level_start, self.max_battery_level)
      # randomly initialize athome with 50/50 chance of being away at hour 0 (8am) or not
      self.at_home = np.random.randint(self.position_space.n)
      # hour may not need to be in the state..?
      self.hour = 1
      self.done = False
       # initial state
      self.state = [self.battery_level, self.hour]

      return self.state

# %%
env = StorageEnv("train.xlsx")

total_cost = 0.0
action_repr = [-2,-1,0,1,2]
battery_charges = []

for episode in range(1):
    # current_day_prices = prices.iloc[episode].tolist()
    # env.reset() # fix the reset function and uncomment when running >1 episodes
    battery_level, hour = env.state
    done=False

    while not done:
      action = random.choice(action_repr)
      # print(env.counter) # counter goes until 26302 = 25208 + 1096, not sure why
      state, reward, done, truncated, info = env.step(action) # get the new state
      battery_level, hour = state

      battery_charges.append(battery_level)

      total_cost += reward

    # finished, all hours*days have been seen
    print(f"At episode {episode+1}, total electricity expenditure is: {total_cost}")

# restrict actions for selling

plt.plot(battery_charges)
# Out:
# At episode 1, total electricity expenditure is: -10810.1719700001

# %%
# self.battery_level = self.state[0]
# self.athome = self.state[1]
# self.hour = self.state[2]
#times to hour state: 8am=0,9am=1,10am=2,11am=3,12pm=4,1pm=5,2pm=6,3pm=7,4pm=8,5pm=9,6pm=10,7pm=11,8pm=12,9pm=13,10pm=14,11pm=15,12am=16,1am=17,2am=18,3am=19,4am=20,5am=21,6am=22,7am=23
# 1. at beginging the battery is >=2 but <=5, which means at the end we need also update to it, time=0
# 2. battery alway >=0  and <=5  *
# 3. from 0 - 10, at home is 50%   *
# 4. at home, charge / discharge   *
# 5. not at home. reduce by 2 levels  *
# 6. overcharge is same as 5  *
# 7. overdischarge is not possible
# 8. price is twice for charging , but for discharging is 1 * price *
# 9. efficiency

class StorageEnv(Env):
    def __init__(self):
        self.values_actions =  [-20, -10, 0, 10, 20]
        self.batteries =  [0, 10, 20, 30, 40, 50]

        self.action_space = Discrete(5, start=-2)
        self.battery_space = Discrete(6, start=0)
        self.position_space = Discrete(2, start=0)

        self.num_hours = 24
        self.min_battery_level_start = 2
        self.min_battery_level = 0
        self.max_battery_level = 5

        # battery level from 0 to 50 (10 incr.), indication car at home or not
        self.observation_space = MultiDiscrete([self.battery_space.n,
                                                self.position_space.n,
                                                self.num_hours])


    def step(self, action):
        ######### at current timestep t
        # battery comsumption at timestep t
        if not self.athome:
          self.battery_level = self.battery_level-2 if self.hour == 0 else self.battery_level

        # pick an acion at timestep t
        if self.athome:
            self.battery_level += action

        # no over-charging above 50kw
        if self.battery_level >= 5:
            self.battery_level = 5

        # should we move the constraints not lower 0 here ??

        ######### update the state for next hour
        # increment to next hour
        self.hour += 1
        # keep the hour 0 ~ 10 same, otherwise athome = True
        self.athome = self.athome if self.hour < 10 else 1
        # update state
        self.state = [self.battery_level, self.athome, self.hour]

        # means that it is 8am in the timestep t+1
        if self.hour == 24:
            self.done = True

        # amount of kwh bought during this step
        kwhs_charged = action * 10

        # to-do get the price here from the outer env loop, in order to get the step's reward; kwhs_charged*price ???
        info = {}

        return self.state, kwhs_charged, self.done, info

    def render(self):
        pass

    def reset(self):
      # initialize battery level randomly between 0 and 6, representing the space 0-50kwh
      self.battery_level = np.random.randint(self.min_battery_level_start, self.max_battery_level)
      # randomly initialize athome with 50/50 chance of being away at hour 0 (8am) or not
      self.athome = np.random.randint(self.position_space.n)
      # hour may not need to be in the state..?
      self.hour = 0
      self.done = False
       # initial state
      self.state = [self.battery_level, self.athome, self.hour]

      return self.state

# %%
env = StorageEnv()

actions = env.action_space
observations = env.observation_space
actions.sample, observations
# Out:
# (<bound method Discrete.sample of Discrete(5, start=-2)>,
#  MultiDiscrete([ 6  2 24]))

# %%
episodes = len(prices)

total_cost = 0.0
min_level = 2
all_actions = np.array([-2,-1,0,1,2])
battery_charges=[]
for episode in range(episodes):
    current_day_prices = prices.iloc[episode].tolist()
    env.reset()
    battery_level, at_home, hour = env.state
    daily_cost = 0.0

    while not env.done:
    # for h in range(24):
      current_hourly_price = current_day_prices[hour] /1000.0 # get old hourly price
      # env.render()
      #

      if not at_home: # check if car is currently away, enforced by overriding previous if statement
          action = random.choice([0])
          # print("action 5", action)

      if at_home:
        if hour == 23:
          legal_actions = get_legal_actions_at_last(all_actions, battery_level)
          action = random.choice(legal_actions)
        else:
          legal_actions = get_legal_actions(all_actions, battery_level)
          action = random.choice(legal_actions)


      state, kwhs_charged, done, info = env.step(action) # get the new state
      battery_level, at_home, hour = state

      # print("current_hourly_price", current_hourly_price)
      # print("reward: ", reward)
      factor = 1.0 if action < 0 else 2.0
      # if hour == 24  and battery_level <2:
      #   print(f"{episode} -  {hour} - {battery_level} - {env.done}")
      reward = (-1) * kwhs_charged * current_hourly_price * factor # add electricity price
      battery_charges.append(battery_level)
      # reward = kwhs_charged
      daily_cost += reward
      # print("type daily: ", type(daily_cost))
      # print("daily: ", daily_cost)
    # finished, t=24
    total_cost += daily_cost
    # print("total:", total_cost)
    # print("type total: ", type(total_cost))

    # done = False

    print(f"At episode {episode+1}, total electricity expenditure is: {daily_cost}")
# restrict actions for seling
# restrict selling at hour 23 to only >20
# Out:
# At episode 1, total electricity expenditure is: -4.8809000000000005
# At episode 2, total electricity expenditure is: -8.1278
# At episode 3, total electricity expenditure is: -3.4595
# At episode 4, total electricity expenditure is: -5.551100000000001
# At episode 5, total electricity expenditure is: -3.0806
# At episode 6, total electricity expenditure is: -7.238299999999999
# At episode 7, total electricity expenditure is: -2.452
# At episode 8, total electricity expenditure is: -6.716
# At episode 9, total electricity expenditure is: -3.2681
# At episode 10, total electricity expenditure is: -3.2055
# At episode 11, total electricity expenditure is: -4.0282
# At episode 12, total electricity expenditure is: -4.2286
# At episode 13, total electricity expenditure is: -3.5252999999999997
# At episode 14, total electricity expenditure is: -6.993900000000001
# At episode 15, total electricity expenditure is: -5.768700000000001
# At episode 16, total electricity expenditure is: -10.983799999999999
# At episode 17, total electricity expenditure is: -2.286
# At episode 18, total electricity expenditure is: -5.1991
# At episode 19, total electricity expenditure is: -3.5877
# At episode 20, total electricity expenditure is: -2.2782999999999998
# At episode 21, total electricity expenditure is: -5.0081
# At episode 22, total electricity expenditure is: -3.5948
# At episode 23, total electricity expenditure is: -5.621600000000001
# At episode 24, total electricity expenditure is: -15.0889
# At episode 25, total electricity expenditure is: -5.7546
# At episode 26, total electricity expenditure is: -9.419700000000002
# At episode 27, total electricity expenditure is: -4.7387
# At episode 28, total electricity expenditure is: -5.789199999999999
# At episode 29, total electricity expenditure is: -11.610600000000003
# At episode 30, total electricity expenditure is: -12.107599999999998
# At episode 31, total electricity expenditure is: -4.277200000000001
# At episode 32, total electricity expenditure is: -8.396700000000001
# At episode 33, total electricity expenditure is: -3.7264
# At episode 34, total electricity expenditure is: -3.9668999999999985
# At episode 35, total electricity expenditure is: -5.8233
# At episode 36, total electricity expenditure is: -7.244299999999999
# At episode 37, total electricity expenditure is: -4.335600000000001
# At episode 38, total electricity expenditure is: -5.084200000000001
# At episode 39, total electricity expenditure is: -4.5
# At episode 40, total electricity expenditure is: -5.4864999999999995
# At episode 41, total electricity expenditure is: -2.6868
# At episode 42, total electricity expenditure is: -4.029
# At episode 43, total electricity expenditure is: -6.624599999999999
# At episode 44, total electricity expenditure is: -1.5697999999999999
# At episode 45, total electricity expenditure is: -2.8442
# At episode 46, total electricity expenditure is: -3.9716
# At episode 47, total electricity expenditure is: -2.3046999999999995
# At episode 48, total electricity expenditure is: -2.236
# At episode 49, total electricity expenditure is: -4.4302
# At episode 50, total electricity expenditure is: -7.062800000000001
# At episode 51, total electricity expenditure is: -5.0546999999999995
# At episode 52, total electricity expenditure is: -5.6431000000000004
# At episode 53, total electricity expenditure is: -5.355599999999998
# At episode 54, total electricity expenditure is: -6.194600000000001
# At episode 55, total electricity expenditure is: -2.5198
# At episode 56, total electricity expenditure is: -1.9013999999999998
# At episode 57, total electricity expenditure is: -2.7171
# At episode 58, total electricity expenditure is: -4.8788
# At episode 59, total electricity expenditure is: -1.8330000000000006
# At episode 60, total electricity expenditure is: -4.269000000000001
# At episode 61, total electricity expenditure is: -1.6204999999999998
# At episode 62, total electricity expenditure is: -2.0646
# At episode 63, total electricity expenditure is: -5.871799999999999
# At episode 64, total electricity expenditure is: -4.9427
# At episode 65, total electricity expenditure is: -2.6201000000000003
# At episode 66, total electricity expenditure is: -2.7501999999999995
# At episode 67, total electricity expenditure is: -3.5515000000000003
# At episode 68, total electricity expenditure is: -4.457400000000002
# At episode 69, total electricity expenditure is: -9.5274
# At episode 70, total electricity expenditure is: -3.4307999999999996
# At episode 71, total electricity expenditure is: -4.9851
# At episode 72, total electricity expenditure is: -3.0029000000000003
# At episode 73, total electricity expenditure is: -4.16
# At episode 74, total electricity expenditure is: -8.746000000000002
# At episode 75, total electricity expenditure is: -8.725299999999999
# At episode 76, total electricity expenditure is: -0.8731
# At episode 77, total electricity expenditure is: -2.5871000000000004
# At episode 78, total electricity expenditure is: -2.9793000000000003
# At episode 79, total electricity expenditure is: -4.2316
# At episode 80, total electricity expenditure is: -5.253299999999999
# At episode 81, total electricity expenditure is: -14.177400000000002
# At episode 82, total electricity expenditure is: -6.6458
# At episode 83, total electricity expenditure is: -3.0844
# At episode 84, total electricity expenditure is: -6.2086999999999986
# At episode 85, total electricity expenditure is: -3.598699999999999
# At episode 86, total electricity expenditure is: -8.741000000000001
# At episode 87, total electricity expenditure is: -8.712999999999997
# At episode 88, total electricity expenditure is: -9.099799999999998
# At episode 89, total electricity expenditure is: -6.090000000000002
# At episode 90, total electricity expenditure is: -4.7074
# At episode 91, total electricity expenditure is: -5.250599999999999
# At episode 92, total electricity expenditure is: -4.9418
# At episode 93, total electricity expenditure is: -3.4112000000000005
# At episode 94, total electricity expenditure is: -4.5596000000000005
# At episode 95, total electricity expenditure is: -1.7916999999999998
# At episode 96, total electricity expenditure is: -2.7520000000000002
# At episode 97, total electricity expenditure is: -4.9012
# At episode 98, total electricity expenditure is: -4.362
# At episode 99, total electricity expenditure is: -2.5423
# At episode 100, total electricity expenditure is: -5.872999999999998
# At episode 101, total electricity expenditure is: -3.2622999999999998
# At episode 102, total electricity expenditure is: -3.2282
# At episode 103, total electricity expenditure is: -2.9679
# At episode 104, total electricity expenditure is: -0.7973999999999999
# At episode 105, total electricity expenditure is: -1.5012
# At episode 106, total electricity expenditure is: -2.1552
# At episode 107, total electricity expenditure is: -3.5295
# At episode 108, total electricity expenditure is: -7.7136
# At episode 109, total electricity expenditure is: -3.6428999999999996
# At episode 110, total electricity expenditure is: -3.3876000000000004
# At episode 111, total electricity expenditure is: -4.187300000000001
# At episode 112, total electricity expenditure is: -2.0843999999999996
# At episode 113, total electricity expenditure is: -4.207400000000001
# At episode 114, total electricity expenditure is: -6.717700000000001
# At episode 115, total electricity expenditure is: -5.3668
# At episode 116, total electricity expenditure is: -4.861199999999999
# At episode 117, total electricity expenditure is: -4.5347
# At episode 118, total electricity expenditure is: -1.4079
# At episode 119, total electricity expenditure is: -0.5789
# At episode 120, total electricity expenditure is: -2.6196
# At episode 121, total electricity expenditure is: -2.7725999999999997
# At episode 122, total electricity expenditure is: -6.1944
# At episode 123, total electricity expenditure is: -5.4011
# At episode 124, total electricity expenditure is: -4.839600000000001
# At episode 125, total electricity expenditure is: -2.6745
# At episode 126, total electricity expenditure is: -2.2679
# At episode 127, total electricity expenditure is: -3.6268000000000002
# At episode 128, total electricity expenditure is: -2.42
# At episode 129, total electricity expenditure is: -1.7441000000000004
# At episode 130, total electricity expenditure is: -2.4669
# At episode 131, total electricity expenditure is: -9.744999999999997
# At episode 132, total electricity expenditure is: -2.3833999999999995
# At episode 133, total electricity expenditure is: -2.6111000000000004
# At episode 134, total electricity expenditure is: -8.355099999999998
# At episode 135, total electricity expenditure is: -3.1221
# At episode 136, total electricity expenditure is: -13.826800000000002
# At episode 137, total electricity expenditure is: -4.655199999999999
# At episode 138, total electricity expenditure is: -3.0785
# At episode 139, total electricity expenditure is: -3.981900000000001
# At episode 140, total electricity expenditure is: -5.947500000000002
# At episode 141, total electricity expenditure is: -7.921799999999999
# At episode 142, total electricity expenditure is: -3.5090000000000003
# At episode 143, total electricity expenditure is: -10.291199999999998
# At episode 144, total electricity expenditure is: -4.218400000000001
# At episode 145, total electricity expenditure is: -2.5261000000000005
# At episode 146, total electricity expenditure is: -3.2850999999999995
# At episode 147, total electricity expenditure is: -1.1847000000000003
# At episode 148, total electricity expenditure is: -5.5114
# At episode 149, total electricity expenditure is: -5.6456
# At episode 150, total electricity expenditure is: -4.6381999999999985
# At episode 151, total electricity expenditure is: -2.0761000000000003
# At episode 152, total electricity expenditure is: -7.6019
# At episode 153, total electricity expenditure is: -1.6127
# At episode 154, total electricity expenditure is: -2.4124
# At episode 155, total electricity expenditure is: -1.8916000000000002
# At episode 156, total electricity expenditure is: -3.7438
# At episode 157, total electricity expenditure is: -5.797199999999999
# At episode 158, total electricity expenditure is: -5.9221
# At episode 159, total electricity expenditure is: -7.326399999999999
# At episode 160, total electricity expenditure is: -4.7753000000000005
# At episode 161, total electricity expenditure is: -2.3594
# At episode 162, total electricity expenditure is: -3.2562
# At episode 163, total electricity expenditure is: -5.575099999999998
# At episode 164, total electricity expenditure is: -3.2685000000000004
# At episode 165, total electricity expenditure is: -1.8972000000000002
# At episode 166, total electricity expenditure is: -1.0165999999999997
# At episode 167, total electricity expenditure is: -1.2543
# At episode 168, total electricity expenditure is: -2.0063
# At episode 169, total electricity expenditure is: -3.3043
# At episode 170, total electricity expenditure is: -4.6316999999999995
# At episode 171, total electricity expenditure is: -3.0615999999999994
# At episode 172, total electricity expenditure is: -4.1044
# At episode 173, total electricity expenditure is: -11.2884
# At episode 174, total electricity expenditure is: -4.705100000000001
# At episode 175, total electricity expenditure is: -3.2589
# At episode 176, total electricity expenditure is: -2.4895
# At episode 177, total electricity expenditure is: -3.5723
# At episode 178, total electricity expenditure is: -2.8076
# At episode 179, total electricity expenditure is: -5.768499999999999
# At episode 180, total electricity expenditure is: -8.429900000000002
# At episode 181, total electricity expenditure is: -3.191
# At episode 182, total electricity expenditure is: -4.091400000000001
# At episode 183, total electricity expenditure is: -2.3768999999999996
# At episode 184, total electricity expenditure is: -11.160799999999998
# At episode 185, total electricity expenditure is: -3.837299999999999
# At episode 186, total electricity expenditure is: -3.0417999999999994
# At episode 187, total electricity expenditure is: -2.7930000000000006
# At episode 188, total electricity expenditure is: -5.548900000000001
# At episode 189, total electricity expenditure is: -4.0722000000000005
# At episode 190, total electricity expenditure is: -10.845299999999998
# At episode 191, total electricity expenditure is: -12.402999999999999
# At episode 192, total electricity expenditure is: -1.2973999999999997
# At episode 193, total electricity expenditure is: -1.7477
# At episode 194, total electricity expenditure is: -4.5831
# At episode 195, total electricity expenditure is: -3.735099999999999
# At episode 196, total electricity expenditure is: -6.6404
# At episode 197, total electricity expenditure is: -11.9072
# At episode 198, total electricity expenditure is: -11.7671
# At episode 199, total electricity expenditure is: -11.7899
# At episode 200, total electricity expenditure is: -7.2033000000000005
# At episode 201, total electricity expenditure is: -9.7715
# At episode 202, total electricity expenditure is: -3.8076000000000008
# At episode 203, total electricity expenditure is: -2.5291999999999994
# At episode 204, total electricity expenditure is: -4.585
# At episode 205, total electricity expenditure is: -3.6548999999999996
# At episode 206, total electricity expenditure is: -6.1198
# At episode 207, total electricity expenditure is: -4.127800000000001
# At episode 208, total electricity expenditure is: -3.7783999999999986
# At episode 209, total electricity expenditure is: -4.4304
# At episode 210, total electricity expenditure is: -3.5637999999999996
# At episode 211, total electricity expenditure is: -4.689800000000001
# At episode 212, total electricity expenditure is: -4.9697
# At episode 213, total electricity expenditure is: -2.3984999999999994
# At episode 214, total electricity expenditure is: -4.637
# At episode 215, total electricity expenditure is: -7.231900000000001
# At episode 216, total electricity expenditure is: -1.5136
# At episode 217, total electricity expenditure is: -3.8162000000000007
# At episode 218, total electricity expenditure is: -4.050099999999999
# At episode 219, total electricity expenditure is: -2.4421999999999993
# At episode 220, total electricity expenditure is: -6.022100000000002
# At episode 221, total electricity expenditure is: -5.7945
# At episode 222, total electricity expenditure is: -3.9119
# At episode 223, total electricity expenditure is: -4.85
# At episode 224, total electricity expenditure is: -5.044300000000001
# At episode 225, total electricity expenditure is: -4.771199999999999
# At episode 226, total electricity expenditure is: -5.302999999999999
# At episode 227, total electricity expenditure is: -3.0650000000000004
# At episode 228, total electricity expenditure is: -1.8848000000000005
# At episode 229, total electricity expenditure is: -2.7455
# At episode 230, total electricity expenditure is: -2.5252
# At episode 231, total electricity expenditure is: -1.5717999999999996
# At episode 232, total electricity expenditure is: -11.055799999999996
# At episode 233, total electricity expenditure is: -2.3129999999999997
# At episode 234, total electricity expenditure is: -5.747400000000001
# At episode 235, total electricity expenditure is: -4.7491
# At episode 236, total electricity expenditure is: -4.616999999999999
# At episode 237, total electricity expenditure is: -7.298399999999999
# At episode 238, total electricity expenditure is: -6.3718
# At episode 239, total electricity expenditure is: -2.8558
# At episode 240, total electricity expenditure is: -2.3956
# At episode 241, total electricity expenditure is: -4.458
# At episode 242, total electricity expenditure is: -7.721299999999999
# At episode 243, total electricity expenditure is: -5.285900000000001
# At episode 244, total electricity expenditure is: -2.6698999999999997
# At episode 245, total electricity expenditure is: -2.8266999999999998
# At episode 246, total electricity expenditure is: -2.9667999999999997
# At episode 247, total electricity expenditure is: -3.7584000000000004
# At episode 248, total electricity expenditure is: -10.198299999999998
# At episode 249, total electricity expenditure is: -11.444100000000004
# At episode 250, total electricity expenditure is: -4.762699999999999
# At episode 251, total electricity expenditure is: -2.4844999999999997
# At episode 252, total electricity expenditure is: -3.219
# At episode 253, total electricity expenditure is: -9.235800000000001
# At episode 254, total electricity expenditure is: -5.628299999999999
# At episode 255, total electricity expenditure is: -9.5449
# At episode 256, total electricity expenditure is: -4.0552
# At episode 257, total electricity expenditure is: -9.1646
# At episode 258, total electricity expenditure is: -3.9177000000000004
# At episode 259, total electricity expenditure is: -4.766900000000001
# At episode 260, total electricity expenditure is: -9.851300000000002
# At episode 261, total electricity expenditure is: -7.248399999999999
# At episode 262, total electricity expenditure is: -13.7534
# At episode 263, total electricity expenditure is: -3.8379
# At episode 264, total electricity expenditure is: -1.8603
# At episode 265, total electricity expenditure is: -7.023999999999997
# At episode 266, total electricity expenditure is: -4.977499999999999
# At episode 267, total electricity expenditure is: -7.210099999999999
# At episode 268, total electricity expenditure is: -5.2909
# At episode 269, total electricity expenditure is: -10.6555
# At episode 270, total electricity expenditure is: -4.85
# At episode 271, total electricity expenditure is: -7.929799999999999
# At episode 272, total electricity expenditure is: -9.488
# At episode 273, total electricity expenditure is: -4.2048
# At episode 274, total electricity expenditure is: -13.0561
# At episode 275, total electricity expenditure is: -2.6532999999999998
# At episode 276, total electricity expenditure is: -3.859
# At episode 277, total electricity expenditure is: -3.2209000000000003
# At episode 278, total electricity expenditure is: -6.5207
# At episode 279, total electricity expenditure is: -4.3401000000000005
# At episode 280, total electricity expenditure is: -2.4522999999999997
# At episode 281, total electricity expenditure is: -15.6188
# At episode 282, total electricity expenditure is: -8.467100000000002
# At episode 283, total electricity expenditure is: -11.803099999999999
# At episode 284, total electricity expenditure is: -10.591199999999999
# At episode 285, total electricity expenditure is: -11.064100000000002
# At episode 286, total electricity expenditure is: -5.3055
# At episode 287, total electricity expenditure is: -7.825700000000003
# At episode 288, total electricity expenditure is: -8.795399999999995
# At episode 289, total electricity expenditure is: -8.4903
# At episode 290, total electricity expenditure is: -7.114799999999999
# At episode 291, total electricity expenditure is: -8.2223
# At episode 292, total electricity expenditure is: -7.3179
# At episode 293, total electricity expenditure is: -4.9603
# At episode 294, total electricity expenditure is: -3.6691000000000003
# At episode 295, total electricity expenditure is: -10.090599999999998
# At episode 296, total electricity expenditure is: -8.5675
# At episode 297, total electricity expenditure is: -11.809400000000002
# At episode 298, total electricity expenditure is: -5.180400000000001
# At episode 299, total electricity expenditure is: -5.273999999999999
# At episode 300, total electricity expenditure is: -8.8455
# At episode 301, total electricity expenditure is: -7.5604
# At episode 302, total electricity expenditure is: -6.241800000000002
# At episode 303, total electricity expenditure is: -7.953600000000001
# At episode 304, total electricity expenditure is: -7.201699999999999
# At episode 305, total electricity expenditure is: -8.7022
# At episode 306, total electricity expenditure is: -16.188700000000004
# At episode 307, total electricity expenditure is: -4.507499999999999
# At episode 308, total electricity expenditure is: -6.601700000000001
# At episode 309, total electricity expenditure is: -17.4341
# At episode 310, total electricity expenditure is: -29.655600000000003
# At episode 311, total electricity expenditure is: -6.749200000000002
# At episode 312, total electricity expenditure is: -11.850599999999996
# At episode 313, total electricity expenditure is: -32.6726
# At episode 314, total electricity expenditure is: -4.6049
# At episode 315, total electricity expenditure is: -18.3643
# At episode 316, total electricity expenditure is: -128.5415
# At episode 317, total electricity expenditure is: -13.813800000000002
# At episode 318, total electricity expenditure is: -9.423300000000001
# At episode 319, total electricity expenditure is: -71.0068
# At episode 320, total electricity expenditure is: -23.859300000000005
# At episode 321, total electricity expenditure is: -12.423200000000003
# At episode 322, total electricity expenditure is: -8.679400000000001
# At episode 323, total electricity expenditure is: -23.0254
# At episode 324, total electricity expenditure is: -40.990199999999994
# At episode 325, total electricity expenditure is: -18.67429999999999
# At episode 326, total electricity expenditure is: -16.4147
# At episode 327, total electricity expenditure is: -16.420799999999996
# At episode 328, total electricity expenditure is: -8.560100000000002
# At episode 329, total electricity expenditure is: -7.3610999999999995
# At episode 330, total electricity expenditure is: -10.225399999999999
# At episode 331, total electricity expenditure is: -16.480999999999998
# At episode 332, total electricity expenditure is: -13.5524
# At episode 333, total electricity expenditure is: -15.575700000000001
# At episode 334, total electricity expenditure is: -7.972800000000001
# At episode 335, total electricity expenditure is: -3.6539999999999995
# At episode 336, total electricity expenditure is: -4.2588
# At episode 337, total electricity expenditure is: -9.257000000000001
# At episode 338, total electricity expenditure is: -5.2697
# At episode 339, total electricity expenditure is: -13.375700000000002
# At episode 340, total electricity expenditure is: -8.8143
# At episode 341, total electricity expenditure is: -5.5722999999999985
# At episode 342, total electricity expenditure is: -8.6036
# At episode 343, total electricity expenditure is: -3.7029
# At episode 344, total electricity expenditure is: -6.088800000000001
# At episode 345, total electricity expenditure is: -16.1508
# At episode 346, total electricity expenditure is: -23.309900000000006
# At episode 347, total electricity expenditure is: -15.702300000000001
# At episode 348, total electricity expenditure is: -8.489
# At episode 349, total electricity expenditure is: -11.618699999999999
# At episode 350, total electricity expenditure is: -12.991900000000001
# At episode 351, total electricity expenditure is: -16.3115
# At episode 352, total electricity expenditure is: -18.9654
# At episode 353, total electricity expenditure is: -19.387900000000005
# At episode 354, total electricity expenditure is: -22.7878
# At episode 355, total electricity expenditure is: -28.969500000000004
# At episode 356, total electricity expenditure is: -12.9627
# At episode 357, total electricity expenditure is: -2.3899999999999992
# At episode 358, total electricity expenditure is: -16.4452
# At episode 359, total electricity expenditure is: -5.450399999999999
# At episode 360, total electricity expenditure is: -6.658199999999999
# At episode 361, total electricity expenditure is: -4.484699999999999
# At episode 362, total electricity expenditure is: -25.018700000000003
# At episode 363, total electricity expenditure is: -4.314400000000001
# At episode 364, total electricity expenditure is: -3.4482000000000004
# At episode 365, total electricity expenditure is: -8.7464
# At episode 366, total electricity expenditure is: -8.817499999999999
# At episode 367, total electricity expenditure is: -10.017299999999999
# At episode 368, total electricity expenditure is: -12.4652
# At episode 369, total electricity expenditure is: -5.587600000000002
# At episode 370, total electricity expenditure is: -8.577699999999998
# At episode 371, total electricity expenditure is: -4.9184
# At episode 372, total electricity expenditure is: -7.058599999999999
# At episode 373, total electricity expenditure is: -7.2341
# At episode 374, total electricity expenditure is: -11.3721
# At episode 375, total electricity expenditure is: -19.6072
# At episode 376, total electricity expenditure is: -10.752099999999999
# At episode 377, total electricity expenditure is: -6.7166
# At episode 378, total electricity expenditure is: -5.859600000000002
# At episode 379, total electricity expenditure is: -8.004299999999999
# At episode 380, total electricity expenditure is: -14.832400000000003
# At episode 381, total electricity expenditure is: -15.7608
# At episode 382, total electricity expenditure is: -9.677999999999999
# At episode 383, total electricity expenditure is: -4.29
# At episode 384, total electricity expenditure is: -6.1404
# At episode 385, total electricity expenditure is: -8.443800000000001
# At episode 386, total electricity expenditure is: -12.275299999999996
# At episode 387, total electricity expenditure is: -11.6212
# At episode 388, total electricity expenditure is: -7.454199999999999
# At episode 389, total electricity expenditure is: -10.5625
# At episode 390, total electricity expenditure is: -11.312800000000001
# At episode 391, total electricity expenditure is: -4.4129000000000005
# At episode 392, total electricity expenditure is: -10.55
# At episode 393, total electricity expenditure is: -13.738900000000001
# At episode 394, total electricity expenditure is: -5.959899999999999
# At episode 395, total electricity expenditure is: -8.3917
# At episode 396, total electricity expenditure is: -15.141800000000002
# At episode 397, total electricity expenditure is: -7.2303
# At episode 398, total electricity expenditure is: -10.285599999999999
# At episode 399, total electricity expenditure is: -15.2683
# At episode 400, total electricity expenditure is: -23.8882
# At episode 401, total electricity expenditure is: -4.9818
# At episode 402, total electricity expenditure is: -7.597800000000002
# At episode 403, total electricity expenditure is: -14.315600000000003
# At episode 404, total electricity expenditure is: -5.5710999999999995
# At episode 405, total electricity expenditure is: -14.557400000000001
# At episode 406, total electricity expenditure is: -5.9883000000000015
# At episode 407, total electricity expenditure is: -19.941500000000005
# At episode 408, total electricity expenditure is: -8.403399999999998
# At episode 409, total electricity expenditure is: -6.230999999999999
# At episode 410, total electricity expenditure is: -13.0326
# At episode 411, total electricity expenditure is: -3.6018999999999997
# At episode 412, total electricity expenditure is: -4.8271
# At episode 413, total electricity expenditure is: -8.8639
# At episode 414, total electricity expenditure is: -16.044400000000003
# At episode 415, total electricity expenditure is: -29.207100000000004
# At episode 416, total electricity expenditure is: -22.695599999999995
# At episode 417, total electricity expenditure is: -4.7349
# At episode 418, total electricity expenditure is: -7.415699999999999
# At episode 419, total electricity expenditure is: -8.1637
# At episode 420, total electricity expenditure is: -10.8621
# At episode 421, total electricity expenditure is: -5.376600000000001
# At episode 422, total electricity expenditure is: -18.9678
# At episode 423, total electricity expenditure is: -10.708199999999998
# At episode 424, total electricity expenditure is: -8.955300000000001
# At episode 425, total electricity expenditure is: -12.7985
# At episode 426, total electricity expenditure is: -9.898500000000002
# At episode 427, total electricity expenditure is: -4.6686
# At episode 428, total electricity expenditure is: -7.3347999999999995
# At episode 429, total electricity expenditure is: -9.6172
# At episode 430, total electricity expenditure is: -12.9182
# At episode 431, total electricity expenditure is: -18.7713
# At episode 432, total electricity expenditure is: -8.9002
# At episode 433, total electricity expenditure is: -13.4359
# At episode 434, total electricity expenditure is: -13.794300000000002
# At episode 435, total electricity expenditure is: -6.193200000000001
# At episode 436, total electricity expenditure is: -11.335499999999998
# At episode 437, total electricity expenditure is: -20.4562
# At episode 438, total electricity expenditure is: -6.597400000000002
# At episode 439, total electricity expenditure is: -11.650300000000001
# At episode 440, total electricity expenditure is: -3.4313
# At episode 441, total electricity expenditure is: -5.103300000000001
# At episode 442, total electricity expenditure is: -12.764399999999998
# At episode 443, total electricity expenditure is: -13.0627
# At episode 444, total electricity expenditure is: -8.6462
# At episode 445, total electricity expenditure is: -9.0184
# At episode 446, total electricity expenditure is: -10.945200000000002
# At episode 447, total electricity expenditure is: -7.396999999999999
# At episode 448, total electricity expenditure is: -6.6217
# At episode 449, total electricity expenditure is: -14.2628
# At episode 450, total electricity expenditure is: -15.551900000000002
# At episode 451, total electricity expenditure is: -13.3077
# At episode 452, total electricity expenditure is: -14.037399999999998
# At episode 453, total electricity expenditure is: -7.118100000000001
# At episode 454, total electricity expenditure is: -7.595600000000001
# At episode 455, total electricity expenditure is: -10.178
# At episode 456, total electricity expenditure is: -17.4847
# At episode 457, total electricity expenditure is: -10.867299999999998
# At episode 458, total electricity expenditure is: -10.724199999999998
# At episode 459, total electricity expenditure is: -14.284600000000001
# At episode 460, total electricity expenditure is: -8.0488
# At episode 461, total electricity expenditure is: -18.1854
# At episode 462, total electricity expenditure is: -8.905299999999999
# At episode 463, total electricity expenditure is: -9.953800000000003
# At episode 464, total electricity expenditure is: -13.421799999999998
# At episode 465, total electricity expenditure is: -23.8966
# At episode 466, total electricity expenditure is: -11.645300000000002
# At episode 467, total electricity expenditure is: -5.390499999999999
# At episode 468, total electricity expenditure is: -7.570600000000001
# At episode 469, total electricity expenditure is: -4.9856
# At episode 470, total electricity expenditure is: -3.9284
# At episode 471, total electricity expenditure is: -8.864499999999998
# At episode 472, total electricity expenditure is: -6.199700000000001
# At episode 473, total electricity expenditure is: -9.4394
# At episode 474, total electricity expenditure is: -20.126999999999995
# At episode 475, total electricity expenditure is: -15.774899999999999
# At episode 476, total electricity expenditure is: -7.890300000000001
# At episode 477, total electricity expenditure is: -7.5257000000000005
# At episode 478, total electricity expenditure is: -16.0477
# At episode 479, total electricity expenditure is: -12.590800000000002
# At episode 480, total electricity expenditure is: -13.730799999999997
# At episode 481, total electricity expenditure is: -25.174500000000002
# At episode 482, total electricity expenditure is: -3.2688000000000006
# At episode 483, total electricity expenditure is: -5.641699999999998
# At episode 484, total electricity expenditure is: -9.9381
# At episode 485, total electricity expenditure is: -5.7713
# At episode 486, total electricity expenditure is: -9.383200000000002
# At episode 487, total electricity expenditure is: -8.196800000000001
# At episode 488, total electricity expenditure is: -11.347900000000003
# At episode 489, total electricity expenditure is: -7.359100000000001
# At episode 490, total electricity expenditure is: -7.802800000000001
# At episode 491, total electricity expenditure is: -18.6086
# At episode 492, total electricity expenditure is: -9.6156
# At episode 493, total electricity expenditure is: -5.3246
# At episode 494, total electricity expenditure is: -14.510299999999999
# At episode 495, total electricity expenditure is: -13.648799999999998
# At episode 496, total electricity expenditure is: -7.858099999999999
# At episode 497, total electricity expenditure is: -1.2538
# At episode 498, total electricity expenditure is: -7.9663
# At episode 499, total electricity expenditure is: -4.3198
# At episode 500, total electricity expenditure is: -5.2226
# At episode 501, total electricity expenditure is: -11.9111
# At episode 502, total electricity expenditure is: -3.3230999999999997
# At episode 503, total electricity expenditure is: -12.860899999999999
# At episode 504, total electricity expenditure is: -8.1378
# At episode 505, total electricity expenditure is: -20.322700000000005
# At episode 506, total electricity expenditure is: -3.974500000000001
# At episode 507, total electricity expenditure is: -6.179900000000001
# At episode 508, total electricity expenditure is: -14.7593
# At episode 509, total electricity expenditure is: -6.329000000000001
# At episode 510, total electricity expenditure is: -6.2586
# At episode 511, total electricity expenditure is: -11.4412
# At episode 512, total electricity expenditure is: -3.6134
# At episode 513, total electricity expenditure is: -15.987399999999996
# At episode 514, total electricity expenditure is: -6.4994
# At episode 515, total electricity expenditure is: -5.885
# At episode 516, total electricity expenditure is: -13.1461
# At episode 517, total electricity expenditure is: -1.4797000000000002
# At episode 518, total electricity expenditure is: -5.2486
# At episode 519, total electricity expenditure is: -24.4224
# At episode 520, total electricity expenditure is: -26.576
# At episode 521, total electricity expenditure is: -7.1842
# At episode 522, total electricity expenditure is: -8.1514
# At episode 523, total electricity expenditure is: -17.336000000000002
# At episode 524, total electricity expenditure is: -11.976099999999999
# At episode 525, total electricity expenditure is: -7.4984
# At episode 526, total electricity expenditure is: -28.1251
# At episode 527, total electricity expenditure is: -5.686800000000002
# At episode 528, total electricity expenditure is: -7.3537
# At episode 529, total electricity expenditure is: -23.543900000000004
# At episode 530, total electricity expenditure is: -11.244100000000001
# At episode 531, total electricity expenditure is: -7.727800000000001
# At episode 532, total electricity expenditure is: -17.375400000000003
# At episode 533, total electricity expenditure is: -16.6802
# At episode 534, total electricity expenditure is: -10.9486
# At episode 535, total electricity expenditure is: -7.984
# At episode 536, total electricity expenditure is: -9.107199999999999
# At episode 537, total electricity expenditure is: -10.801000000000002
# At episode 538, total electricity expenditure is: -10.502500000000001
# At episode 539, total electricity expenditure is: -4.058999999999999
# At episode 540, total electricity expenditure is: -6.821199999999999
# At episode 541, total electricity expenditure is: -7.981300000000002
# At episode 542, total electricity expenditure is: -10.267900000000001
# At episode 543, total electricity expenditure is: -24.2009
# At episode 544, total electricity expenditure is: -26.305500000000002
# At episode 545, total electricity expenditure is: -5.7419
# At episode 546, total electricity expenditure is: -9.977600000000002
# At episode 547, total electricity expenditure is: -17.944300000000002
# At episode 548, total electricity expenditure is: -8.427200000000001
# At episode 549, total electricity expenditure is: -23.094
# At episode 550, total electricity expenditure is: -25.3107
# At episode 551, total electricity expenditure is: -12.465999999999998
# At episode 552, total electricity expenditure is: -5.1747
# At episode 553, total electricity expenditure is: -5.060200000000001
# At episode 554, total electricity expenditure is: -10.009399999999998
# At episode 555, total electricity expenditure is: -13.5061
# At episode 556, total electricity expenditure is: -10.112200000000001
# At episode 557, total electricity expenditure is: -13.566900000000002
# At episode 558, total electricity expenditure is: -17.0404
# At episode 559, total electricity expenditure is: -12.433399999999997
# At episode 560, total electricity expenditure is: -12.012100000000002
# At episode 561, total electricity expenditure is: -6.0984
# At episode 562, total electricity expenditure is: -6.021199999999999
# At episode 563, total electricity expenditure is: -9.1881
# At episode 564, total electricity expenditure is: -15.524599999999998
# At episode 565, total electricity expenditure is: -7.289199999999999
# At episode 566, total electricity expenditure is: -2.5460000000000003
# At episode 567, total electricity expenditure is: -7.4387
# At episode 568, total electricity expenditure is: -18.826200000000004
# At episode 569, total electricity expenditure is: -13.731200000000001
# At episode 570, total electricity expenditure is: -13.9502
# At episode 571, total electricity expenditure is: -6.430300000000001
# At episode 572, total electricity expenditure is: -5.6664
# At episode 573, total electricity expenditure is: -5.8249
# At episode 574, total electricity expenditure is: -7.0493
# At episode 575, total electricity expenditure is: -5.0907
# At episode 576, total electricity expenditure is: -8.8232
# At episode 577, total electricity expenditure is: -10.774099999999997
# At episode 578, total electricity expenditure is: -7.1297999999999995
# At episode 579, total electricity expenditure is: -10.3366
# At episode 580, total electricity expenditure is: -4.981199999999999
# At episode 581, total electricity expenditure is: -3.8679000000000006
# At episode 582, total electricity expenditure is: -10.4647
# At episode 583, total electricity expenditure is: -7.9943
# At episode 584, total electricity expenditure is: -15.1281
# At episode 585, total electricity expenditure is: -12.014699999999998
# At episode 586, total electricity expenditure is: -11.694700000000001
# At episode 587, total electricity expenditure is: -4.152500000000001
# At episode 588, total electricity expenditure is: -5.969499999999999
# At episode 589, total electricity expenditure is: -3.5047
# At episode 590, total electricity expenditure is: -8.589699999999999
# At episode 591, total electricity expenditure is: -6.989899999999998
# At episode 592, total electricity expenditure is: -5.4568
# At episode 593, total electricity expenditure is: -5.015000000000001
# At episode 594, total electricity expenditure is: -8.4448
# At episode 595, total electricity expenditure is: -7.881099999999998
# At episode 596, total electricity expenditure is: -4.093300000000001
# At episode 597, total electricity expenditure is: -10.127600000000003
# At episode 598, total electricity expenditure is: -4.5896
# At episode 599, total electricity expenditure is: -6.5628
# At episode 600, total electricity expenditure is: -12.1771
# At episode 601, total electricity expenditure is: -7.303
# At episode 602, total electricity expenditure is: -6.7291000000000025
# At episode 603, total electricity expenditure is: -20.102599999999995
# At episode 604, total electricity expenditure is: -10.565999999999999
# At episode 605, total electricity expenditure is: -16.1454
# At episode 606, total electricity expenditure is: -30.077600000000004
# At episode 607, total electricity expenditure is: -9.386000000000001
# At episode 608, total electricity expenditure is: -14.754400000000002
# At episode 609, total electricity expenditure is: -9.887900000000002
# At episode 610, total electricity expenditure is: -17.6527
# At episode 611, total electricity expenditure is: -28.500400000000006
# At episode 612, total electricity expenditure is: -24.7606
# At episode 613, total electricity expenditure is: -13.906
# At episode 614, total electricity expenditure is: -8.4302
# At episode 615, total electricity expenditure is: -18.912800000000004
# At episode 616, total electricity expenditure is: -5.742699999999999
# At episode 617, total electricity expenditure is: -14.1028
# At episode 618, total electricity expenditure is: -8.179499999999999
# At episode 619, total electricity expenditure is: -29.238800000000005
# At episode 620, total electricity expenditure is: -13.016299999999996
# At episode 621, total electricity expenditure is: -20.012999999999995
# At episode 622, total electricity expenditure is: -24.022400000000005
# At episode 623, total electricity expenditure is: -9.565800000000001
# At episode 624, total electricity expenditure is: -8.297799999999999
# At episode 625, total electricity expenditure is: -16.835099999999997
# At episode 626, total electricity expenditure is: -8.8367
# At episode 627, total electricity expenditure is: -10.2529
# At episode 628, total electricity expenditure is: -8.773
# At episode 629, total electricity expenditure is: -21.956799999999994
# At episode 630, total electricity expenditure is: -10.5404
# At episode 631, total electricity expenditure is: -9.422
# At episode 632, total electricity expenditure is: -17.360500000000002
# At episode 633, total electricity expenditure is: -25.4243
# At episode 634, total electricity expenditure is: -22.8827
# At episode 635, total electricity expenditure is: -18.7249
# At episode 636, total electricity expenditure is: -7.913599999999999
# At episode 637, total electricity expenditure is: -9.855300000000002
# At episode 638, total electricity expenditure is: -14.0597
# At episode 639, total electricity expenditure is: -9.507
# At episode 640, total electricity expenditure is: -16.3675
# At episode 641, total electricity expenditure is: -15.170500000000006
# At episode 642, total electricity expenditure is: -11.204199999999998
# At episode 643, total electricity expenditure is: -10.126
# At episode 644, total electricity expenditure is: -10.6211
# At episode 645, total electricity expenditure is: -9.5288
# At episode 646, total electricity expenditure is: -24.7033
# At episode 647, total electricity expenditure is: -11.0315
# At episode 648, total electricity expenditure is: -40.78820000000001
# At episode 649, total electricity expenditure is: -16.3572
# At episode 650, total electricity expenditure is: -21.361700000000003
# At episode 651, total electricity expenditure is: -6.980700000000001
# At episode 652, total electricity expenditure is: -13.710199999999997
# At episode 653, total electricity expenditure is: -11.476000000000003
# At episode 654, total electricity expenditure is: -11.1587
# At episode 655, total electricity expenditure is: -5.9702
# At episode 656, total electricity expenditure is: -13.715499999999999
# At episode 657, total electricity expenditure is: -10.3602
# At episode 658, total electricity expenditure is: -10.223300000000002
# At episode 659, total electricity expenditure is: -31.389799999999997
# At episode 660, total electricity expenditure is: -10.488500000000002
# At episode 661, total electricity expenditure is: -13.405899999999997
# At episode 662, total electricity expenditure is: -10.296500000000002
# At episode 663, total electricity expenditure is: -11.582199999999998
# At episode 664, total electricity expenditure is: -12.940100000000003
# At episode 665, total electricity expenditure is: -9.896999999999998
# At episode 666, total electricity expenditure is: -7.463800000000002
# At episode 667, total electricity expenditure is: -15.9901
# At episode 668, total electricity expenditure is: -10.8054
# At episode 669, total electricity expenditure is: -16.61
# At episode 670, total electricity expenditure is: -17.1752
# At episode 671, total electricity expenditure is: -4.838
# At episode 672, total electricity expenditure is: -11.726400000000005
# At episode 673, total electricity expenditure is: -13.127100000000002
# At episode 674, total electricity expenditure is: -8.7662
# At episode 675, total electricity expenditure is: -11.849899999999998
# At episode 676, total electricity expenditure is: -4.6309000000000005
# At episode 677, total electricity expenditure is: -9.172799999999999
# At episode 678, total electricity expenditure is: -14.490499999999999
# At episode 679, total electricity expenditure is: -9.178300000000002
# At episode 680, total electricity expenditure is: -7.4019
# At episode 681, total electricity expenditure is: -10.2768
# At episode 682, total electricity expenditure is: -7.3242
# At episode 683, total electricity expenditure is: -18.4146
# At episode 684, total electricity expenditure is: -11.315800000000001
# At episode 685, total electricity expenditure is: -5.680800000000001
# At episode 686, total electricity expenditure is: -4.5796
# At episode 687, total electricity expenditure is: -16.9994
# At episode 688, total electricity expenditure is: -13.4017
# At episode 689, total electricity expenditure is: -24.298999999999996
# At episode 690, total electricity expenditure is: -11.7316
# At episode 691, total electricity expenditure is: -7.6217999999999995
# At episode 692, total electricity expenditure is: -10.435500000000003
# At episode 693, total electricity expenditure is: -15.194599999999998
# At episode 694, total electricity expenditure is: -9.7771
# At episode 695, total electricity expenditure is: -19.9433
# At episode 696, total electricity expenditure is: -14.629600000000002
# At episode 697, total electricity expenditure is: -9.905700000000001
# At episode 698, total electricity expenditure is: -9.7802
# At episode 699, total electricity expenditure is: -14.8751
# At episode 700, total electricity expenditure is: -7.782399999999999
# At episode 701, total electricity expenditure is: -10.293400000000005
# At episode 702, total electricity expenditure is: -14.430899999999998
# At episode 703, total electricity expenditure is: -9.6405
# At episode 704, total electricity expenditure is: -10.4691
# At episode 705, total electricity expenditure is: -11.895499999999998
# At episode 706, total electricity expenditure is: -4.942699999999999
# At episode 707, total electricity expenditure is: -12.598200000000002
# At episode 708, total electricity expenditure is: -10.438
# At episode 709, total electricity expenditure is: -9.3435
# At episode 710, total electricity expenditure is: -4.069800000000001
# At episode 711, total electricity expenditure is: -11.2554
# At episode 712, total electricity expenditure is: -9.854899999999999
# At episode 713, total electricity expenditure is: -14.682999999999998
# At episode 714, total electricity expenditure is: -19.110100000000003
# At episode 715, total electricity expenditure is: -16.2737
# At episode 716, total electricity expenditure is: -10.385500000000002
# At episode 717, total electricity expenditure is: -7.1872
# At episode 718, total electricity expenditure is: -10.3481
# At episode 719, total electricity expenditure is: -8.7145
# At episode 720, total electricity expenditure is: -8.839000000000004
# At episode 721, total electricity expenditure is: -5.858099999999999
# At episode 722, total electricity expenditure is: -8.186199999999998
# At episode 723, total electricity expenditure is: -8.662499999999998
# At episode 724, total electricity expenditure is: -7.3294
# At episode 725, total electricity expenditure is: -4.199
# At episode 726, total electricity expenditure is: -14.492300000000002
# At episode 727, total electricity expenditure is: -10.4602
# At episode 728, total electricity expenditure is: -10.3444
# At episode 729, total electricity expenditure is: -5.089499999999999
# At episode 730, total electricity expenditure is: -5.74
# At episode 731, total electricity expenditure is: -11.982400000000002
# At episode 732, total electricity expenditure is: -7.3561
# At episode 733, total electricity expenditure is: -14.435300000000002
# At episode 734, total electricity expenditure is: -4.592500000000001
# At episode 735, total electricity expenditure is: -11.557700000000002
# At episode 736, total electricity expenditure is: -12.683600000000002
# At episode 737, total electricity expenditure is: -12.2058
# At episode 738, total electricity expenditure is: -16.262900000000002
# At episode 739, total electricity expenditure is: -9.975600000000002
# At episode 740, total electricity expenditure is: -14.294400000000001
# At episode 741, total electricity expenditure is: -6.154699999999999
# At episode 742, total electricity expenditure is: -6.9132
# At episode 743, total electricity expenditure is: -7.599899999999998
# ...
# At episode 850, total electricity expenditure is: -4.1556
# At episode 851, total electricity expenditure is: -4.246899999999999
# At episode 852, total electricity expenditure is: -5.1424
# At episode 853, total electricity expenditure is: -3.9375
# At episode 854, total electricity expenditure is: -4.5163
# At episode 855, total electricity expenditure is: -2.9547
# At episode 856, total electricity expenditure is: -1.9695999999999996
# At episode 857, total electricity expenditure is: -3.8531999999999984
# At episode 858, total electricity expenditure is: -6.6673
# At episode 859, total electricity expenditure is: -5.0889
# At episode 860, total electricity expenditure is: -1.9944000000000004
# At episode 861, total electricity expenditure is: -2.9102999999999994
# At episode 862, total electricity expenditure is: -5.816
# At episode 863, total electricity expenditure is: -9.199200000000001
# At episode 864, total electricity expenditure is: -12.152800000000001
# At episode 865, total electricity expenditure is: -7.868299999999998
# At episode 866, total electricity expenditure is: -4.403700000000001
# At episode 867, total electricity expenditure is: -3.9245000000000005
# At episode 868, total electricity expenditure is: -8.041900000000002
# At episode 869, total electricity expenditure is: -3.3819
# At episode 870, total electricity expenditure is: -3.867800000000001
# At episode 871, total electricity expenditure is: -4.1812
# At episode 872, total electricity expenditure is: -3.9776
# At episode 873, total electricity expenditure is: -4.616600000000001
# At episode 874, total electricity expenditure is: -3.272399999999999
# At episode 875, total electricity expenditure is: -5.004700000000001
# At episode 876, total electricity expenditure is: -6.515199999999998
# At episode 877, total electricity expenditure is: -2.7897
# At episode 878, total electricity expenditure is: -4.495200000000001
# At episode 879, total electricity expenditure is: -6.8747
# At episode 880, total electricity expenditure is: -3.3503999999999996
# At episode 881, total electricity expenditure is: -0.3222999999999999
# At episode 882, total electricity expenditure is: -3.2191000000000005
# At episode 883, total electricity expenditure is: -0.9995
# At episode 884, total electricity expenditure is: -3.3656000000000006
# At episode 885, total electricity expenditure is: -4.7661999999999995
# At episode 886, total electricity expenditure is: -8.5907
# At episode 887, total electricity expenditure is: -9.6957
# At episode 888, total electricity expenditure is: -1.0818999999999996
# At episode 889, total electricity expenditure is: -5.729300000000002
# At episode 890, total electricity expenditure is: -11.6137
# At episode 891, total electricity expenditure is: -8.1732
# At episode 892, total electricity expenditure is: -6.8416
# At episode 893, total electricity expenditure is: -5.3958
# At episode 894, total electricity expenditure is: -4.2107
# At episode 895, total electricity expenditure is: -2.4227000000000007
# At episode 896, total electricity expenditure is: -3.0403
# At episode 897, total electricity expenditure is: -10.2105
# At episode 898, total electricity expenditure is: -4.7491
# At episode 899, total electricity expenditure is: -7.670000000000002
# At episode 900, total electricity expenditure is: -13.8921
# At episode 901, total electricity expenditure is: -14.054799999999997
# At episode 902, total electricity expenditure is: -7.0063
# At episode 903, total electricity expenditure is: -1.9223999999999997
# At episode 904, total electricity expenditure is: -5.6709
# At episode 905, total electricity expenditure is: -4.522799999999999
# At episode 906, total electricity expenditure is: -6.3729000000000005
# At episode 907, total electricity expenditure is: -5.988000000000001
# At episode 908, total electricity expenditure is: -10.3274
# At episode 909, total electricity expenditure is: -5.155099999999998
# At episode 910, total electricity expenditure is: -7.7296
# At episode 911, total electricity expenditure is: -8.502699999999999
# At episode 912, total electricity expenditure is: -9.302
# At episode 913, total electricity expenditure is: -5.225200000000001
# At episode 914, total electricity expenditure is: -6.8703
# At episode 915, total electricity expenditure is: -5.178800000000001
# At episode 916, total electricity expenditure is: -5.768000000000001
# At episode 917, total electricity expenditure is: -3.9261
# At episode 918, total electricity expenditure is: -9.601199999999999
# At episode 919, total electricity expenditure is: -3.7055999999999996
# At episode 920, total electricity expenditure is: -9.176099999999998
# At episode 921, total electricity expenditure is: -4.219099999999999
# At episode 922, total electricity expenditure is: -3.8014
# At episode 923, total electricity expenditure is: -6.923200000000001
# At episode 924, total electricity expenditure is: -10.332699999999999
# At episode 925, total electricity expenditure is: -3.6597
# At episode 926, total electricity expenditure is: -8.354600000000001
# At episode 927, total electricity expenditure is: -8.339400000000001
# At episode 928, total electricity expenditure is: -5.239199999999999
# At episode 929, total electricity expenditure is: -5.3806
# At episode 930, total electricity expenditure is: -3.946100000000001
# At episode 931, total electricity expenditure is: -3.4782
# At episode 932, total electricity expenditure is: -6.0589
# At episode 933, total electricity expenditure is: -7.138299999999999
# At episode 934, total electricity expenditure is: -10.003599999999999
# At episode 935, total electricity expenditure is: -5.500800000000001
# At episode 936, total electricity expenditure is: -3.1056999999999997
# At episode 937, total electricity expenditure is: -4.8404
# At episode 938, total electricity expenditure is: -3.0446999999999997
# At episode 939, total electricity expenditure is: -2.3137
# At episode 940, total electricity expenditure is: -3.1362000000000005
# At episode 941, total electricity expenditure is: -3.7889999999999993
# At episode 942, total electricity expenditure is: -8.9624
# At episode 943, total electricity expenditure is: -3.0555
# At episode 944, total electricity expenditure is: -3.7653999999999996
# At episode 945, total electricity expenditure is: -1.8139
# At episode 946, total electricity expenditure is: -1.9958
# At episode 947, total electricity expenditure is: -6.202800000000002
# At episode 948, total electricity expenditure is: -4.2178
# At episode 949, total electricity expenditure is: -4.0512999999999995
# At episode 950, total electricity expenditure is: -5.541900000000001
# At episode 951, total electricity expenditure is: -4.448300000000001
# At episode 952, total electricity expenditure is: -5.3226
# At episode 953, total electricity expenditure is: -6.894099999999999
# At episode 954, total electricity expenditure is: -5.2063
# At episode 955, total electricity expenditure is: -3.968099999999999
# At episode 956, total electricity expenditure is: -10.624699999999999
# At episode 957, total electricity expenditure is: -3.9349000000000003
# At episode 958, total electricity expenditure is: -3.1622999999999992
# At episode 959, total electricity expenditure is: -2.9847
# At episode 960, total electricity expenditure is: -5.583
# At episode 961, total electricity expenditure is: -4.216799999999999
# At episode 962, total electricity expenditure is: -4.8215
# At episode 963, total electricity expenditure is: -6.3986
# At episode 964, total electricity expenditure is: -5.5389
# At episode 965, total electricity expenditure is: -4.722
# At episode 966, total electricity expenditure is: -6.9487000000000005
# At episode 967, total electricity expenditure is: -3.6552000000000007
# At episode 968, total electricity expenditure is: -5.476400000000001
# At episode 969, total electricity expenditure is: -5.324199999999999
# At episode 970, total electricity expenditure is: -14.774799999999997
# At episode 971, total electricity expenditure is: -5.6328
# At episode 972, total electricity expenditure is: -3.365
# At episode 973, total electricity expenditure is: -3.8135999999999997
# At episode 974, total electricity expenditure is: -7.1152000000000015
# At episode 975, total electricity expenditure is: -9.667300000000003
# At episode 976, total electricity expenditure is: -6.5782
# At episode 977, total electricity expenditure is: -3.742
# At episode 978, total electricity expenditure is: -4.072100000000001
# At episode 979, total electricity expenditure is: -5.173900000000001
# At episode 980, total electricity expenditure is: -3.467
# At episode 981, total electricity expenditure is: -5.8687999999999985
# At episode 982, total electricity expenditure is: -16.245400000000004
# At episode 983, total electricity expenditure is: -5.963900000000001
# At episode 984, total electricity expenditure is: -4.7999
# At episode 985, total electricity expenditure is: -4.4224
# At episode 986, total electricity expenditure is: -4.799099999999999
# At episode 987, total electricity expenditure is: -3.1186000000000003
# At episode 988, total electricity expenditure is: -0.9736
# At episode 989, total electricity expenditure is: -6.431100000000001
# At episode 990, total electricity expenditure is: -3.7755
# At episode 991, total electricity expenditure is: -3.9916000000000005
# At episode 992, total electricity expenditure is: -9.642700000000001
# At episode 993, total electricity expenditure is: -5.579699999999999
# At episode 994, total electricity expenditure is: -8.051299999999998
# At episode 995, total electricity expenditure is: -5.524100000000001
# At episode 996, total electricity expenditure is: -12.670000000000002
# At episode 997, total electricity expenditure is: -4.466200000000001
# At episode 998, total electricity expenditure is: -7.111399999999999
# At episode 999, total electricity expenditure is: -11.159899999999997
# At episode 1000, total electricity expenditure is: -2.4244
# At episode 1001, total electricity expenditure is: -8.7454
# At episode 1002, total electricity expenditure is: -4.7293
# At episode 1003, total electricity expenditure is: -8.876999999999999
# At episode 1004, total electricity expenditure is: -4.8024000000000004
# At episode 1005, total electricity expenditure is: -9.5657
# At episode 1006, total electricity expenditure is: -4.6602
# At episode 1007, total electricity expenditure is: -2.0877999999999997
# At episode 1008, total electricity expenditure is: -10.5713
# At episode 1009, total electricity expenditure is: -3.2953
# At episode 1010, total electricity expenditure is: -8.463000000000001
# At episode 1011, total electricity expenditure is: -4.6486
# At episode 1012, total electricity expenditure is: -8.0175
# At episode 1013, total electricity expenditure is: -9.638799999999998
# At episode 1014, total electricity expenditure is: -1.4552
# At episode 1015, total electricity expenditure is: -3.3285
# At episode 1016, total electricity expenditure is: -3.8151
# At episode 1017, total electricity expenditure is: -5.881900000000001
# At episode 1018, total electricity expenditure is: -3.7818000000000005
# At episode 1019, total electricity expenditure is: -5.753400000000001
# At episode 1020, total electricity expenditure is: -8.3126
# At episode 1021, total electricity expenditure is: -7.6349
# At episode 1022, total electricity expenditure is: -7.839100000000002
# At episode 1023, total electricity expenditure is: -5.275099999999999
# At episode 1024, total electricity expenditure is: -8.5288
# At episode 1025, total electricity expenditure is: -8.6175
# At episode 1026, total electricity expenditure is: -9.6028
# At episode 1027, total electricity expenditure is: -7.7746999999999975
# At episode 1028, total electricity expenditure is: -2.9212000000000002
# At episode 1029, total electricity expenditure is: -3.3745000000000003
# At episode 1030, total electricity expenditure is: -8.2487
# At episode 1031, total electricity expenditure is: -9.008400000000002
# At episode 1032, total electricity expenditure is: -5.476
# At episode 1033, total electricity expenditure is: -9.848500000000001
# At episode 1034, total electricity expenditure is: -5.2208000000000006
# At episode 1035, total electricity expenditure is: -4.4529000000000005
# At episode 1036, total electricity expenditure is: -5.870900000000001
# At episode 1037, total electricity expenditure is: -10.798800000000002
# At episode 1038, total electricity expenditure is: -4.529599999999999
# At episode 1039, total electricity expenditure is: -19.7681
# At episode 1040, total electricity expenditure is: -4.5376
# At episode 1041, total electricity expenditure is: -3.8273
# At episode 1042, total electricity expenditure is: -4.136299999999999
# At episode 1043, total electricity expenditure is: -4.8426
# At episode 1044, total electricity expenditure is: -6.902200000000001
# At episode 1045, total electricity expenditure is: -8.525999999999998
# At episode 1046, total electricity expenditure is: -5.9446
# At episode 1047, total electricity expenditure is: -5.236000000000001
# At episode 1048, total electricity expenditure is: -4.228199999999999
# At episode 1049, total electricity expenditure is: -4.6864
# At episode 1050, total electricity expenditure is: -2.0505
# At episode 1051, total electricity expenditure is: -6.5731
# At episode 1052, total electricity expenditure is: -10.615499999999999
# At episode 1053, total electricity expenditure is: -5.6604
# At episode 1054, total electricity expenditure is: -4.4376
# At episode 1055, total electricity expenditure is: -6.528100000000001
# At episode 1056, total electricity expenditure is: -3.3920000000000003
# At episode 1057, total electricity expenditure is: -3.4229000000000003
# At episode 1058, total electricity expenditure is: -7.1562
# At episode 1059, total electricity expenditure is: -5.6621999999999995
# At episode 1060, total electricity expenditure is: -11.676099999999998
# At episode 1061, total electricity expenditure is: -10.883600000000001
# At episode 1062, total electricity expenditure is: -5.390499999999999
# At episode 1063, total electricity expenditure is: -7.091400000000001
# At episode 1064, total electricity expenditure is: -3.4764
# At episode 1065, total electricity expenditure is: -5.3425
# At episode 1066, total electricity expenditure is: -6.212000000000001
# At episode 1067, total electricity expenditure is: -4.0228
# At episode 1068, total electricity expenditure is: -7.9896
# At episode 1069, total electricity expenditure is: -16.4233
# At episode 1070, total electricity expenditure is: -4.2275
# At episode 1071, total electricity expenditure is: -2.0441000000000003
# At episode 1072, total electricity expenditure is: -4.4460999999999995
# At episode 1073, total electricity expenditure is: -4.0689
# At episode 1074, total electricity expenditure is: -16.7096
# At episode 1075, total electricity expenditure is: -10.063600000000001
# At episode 1076, total electricity expenditure is: -10.320099999999998
# At episode 1077, total electricity expenditure is: -16.5197
# At episode 1078, total electricity expenditure is: -8.6754
# At episode 1079, total electricity expenditure is: -3.005299999999999
# At episode 1080, total electricity expenditure is: -5.179799999999999
# At episode 1081, total electricity expenditure is: -6.661899999999999
# At episode 1082, total electricity expenditure is: -20.245699999999992
# At episode 1083, total electricity expenditure is: -5.7086000000000015
# At episode 1084, total electricity expenditure is: -22.144599999999997
# At episode 1085, total electricity expenditure is: -7.7878
# At episode 1086, total electricity expenditure is: -5.746899999999999
# At episode 1087, total electricity expenditure is: -9.7932
# At episode 1088, total electricity expenditure is: -10.635600000000004
# At episode 1089, total electricity expenditure is: -5.398600000000001
# At episode 1090, total electricity expenditure is: -5.3164
# At episode 1091, total electricity expenditure is: -4.397599999999999
# At episode 1092, total electricity expenditure is: -11.6618
# At episode 1093, total electricity expenditure is: -4.973300000000001
# At episode 1094, total electricity expenditure is: -4.656599999999999
# At episode 1095, total electricity expenditure is: -6.530800000000001

# %%
print(total_cost)
# Out:
# -9126.421100000001

# %%
class QAgent():

    def __init__(self, env_name, discount_rate = 0.95, bin_size = 20):

        '''
        Params:

        env_name = name of the specific environment that the agent wants to solve
        discount_rate = discount rate used for future rewards
        bin_size = number of bins used for discretizing the state space

        '''

        #create an environment
        self.env_name = env_name
        self.env = gym.make(env_name)

        #Set the discount rate
        self.discount_rate = discount_rate

        #The algorithm has then 3 different actions
        #0: Accelerate to the left
        #1: Don't accelerate
        #2: Accelerate to the right
        #self.action_space = range(self.env.action_space.n)

        self.action_space = self.env.action_space.n

        #Set the bin size
        self.bin_size = bin_size

        #State incorporates the observation state
        #State[0] is x position
        #State[1] is velocity

        #Get the low and high values of the environment space
        self.low = self.env.observation_space.low
        self.high = self.env.observation_space.high

        #Create bins for both observation features, i.e. x-position and velocity

        self.bin_x = np.linspace(self.low[0], self.high[0], self.bin_size)

        '''
        ToDo:

        Please create the bins for the velocity feature in the same manner and call this variable self.bin_velocity!
        '''

        self.bin_velocity = np.linspace(self.low[1], self.high[1], self.bin_size)


        #Put the two bins together
        self.bins = [self.bin_x, self.bin_velocity]

    def discretize_state(self, state):

        '''
        Params:
        state = state observation that needs to be discretized


        Returns:
        discretized state
        '''
        #Now we can make use of the function np.digitize and bin it
        self.state = state

        #Create an empty state
        digitized_state = []

        for i in range(len(self.bins)):
            digitized_state.append(np.digitize(self.state[i], self.bins[i])-1)

        #Returns the discretized state from an observation
        return digitized_state

    def create_Q_table(self):
        self.state_space = self.bin_size - 1
        #Initialize all values in the Q-table to zero
        #Matrix of dimension state_space * state_space * action_space with zero entries

        '''
        ToDo:
        Initialize a zero matrix of dimension state_space * state_space * action_space and call it self.Qtable!
        '''

        self.Qtable = np.zeros((self.bin_size,self.bin_size,self.action_space))

    def train(self, simulations, learning_rate, epsilon = 0.05, epsilon_decay = 1000, adaptive_epsilon = False,
              adapting_learning_rate = False):

        '''
        Params:

        simulations = number of episodes of a game to run
        learning_rate = learning rate for the update equation
        epsilon = epsilon value for epsilon-greedy algorithm
        epsilon_decay = number of full episodes (games) over which the epsilon value will decay to its final value
        adaptive_epsilon = boolean that indicates if the epsilon rate will decay over time or not
        adapting_learning_rate = boolean that indicates if the learning rate should be adaptive or not

        '''

        #Initialize variables that keep track of the rewards

        self.rewards = []
        self.average_rewards = []

        #Call the Q table function to create an initialized Q table
        self.create_Q_table()

        #Set epsilon rate, epsilon decay and learning rate
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.learning_rate = learning_rate

        #Set start epsilon, so here we want a starting exploration rate of 1
        self.epsilon_start = 1
        self.epsilon_end = 0.05

        #If we choose adaptive learning rate, we start with a value of 1 and decay it over time!
        if adapting_learning_rate:
            self.learning_rate = 1

        for i in range(simulations):

            if i % 5000 == 0:
                print(f'Please wait, the algorithm is learning! The current simulation is {i}')
            #Initialize the state
            state = self.env.reset()[0] # reset returns a dict, need to take the 0th entry

            #Set a variable that flags if an episode has terminated
            done = False

            #Discretize the state space

            state = self.discretize_state(state)

            #Set the rewards to 0
            total_rewards = 0

            #If adaptive epsilon rate
            if adaptive_epsilon:
                self.epsilon = np.interp(i, [0, self.epsilon_decay], [self.epsilon_start, self.epsilon_end])

                #Logging just to check it decays as we want it to do, we just print out the first three statements
                if i % 500 == 0 and i <= 1500:
                    print(f"The current epsilon rate is {self.epsilon}")

            #Loop until an episode has terminated
            while not done:

                #Pick an action based on epsilon greedy

                '''
                ToDo: Write the if statement that picks a random action
                Tip: Make use of np.random.uniform() and the self.epsilon to make a decision!
                Tip: You can also make use of the method sample() of the self.env.action_space
                    to generate a random action!
                '''

                #Pick random action

                if np.random.uniform(0,1) <= self.epsilon:
                    action = np.random.randint(0,self.action_space)

                #Pick a greedy action

                else:
                    action = np.argmax(self.Qtable[state[0], state[1], :])

                #Now sample the next_state, reward, done and info from the environment

                next_state, reward, terminated, truncated, info = self.env.step(action) # step returns 5 outputs
                done = terminated or truncated

                #Now discretize the next_state
                next_state = self.discretize_state(next_state)

                #Target value
                Q_target = (reward + self.discount_rate*np.max(self.Qtable[next_state[0], next_state[1]]))

                #Calculate the Temporal difference error (delta)
                '''
                ToDo: Calculate the Temporal difference error (delta)
                Tip: Make use of slide 17 from the Q-learning slides on Canvas
                '''

                delta = self.learning_rate * (Q_target - self.Qtable[state[0], state[1], action])

                #Update the Q-value
                self.Qtable[state[0], state[1], action] = self.Qtable[state[0], state[1], action] + delta

                #Update the reward and the hyperparameters
                total_rewards += reward
                state = next_state

            if adapting_learning_rate:
                self.learning_rate = self.learning_rate/np.sqrt(i+1)

            self.rewards.append(total_rewards)

            #Calculate the average score over 100 episodes
            if i % 100 == 0:
                self.average_rewards.append(np.mean(self.rewards))

                #Initialize a new reward list, as otherwise the average values would reflect all rewards!
                self.rewards = []

        print('The simulation is done!')

    def visualize_rewards(self):
        plt.figure(figsize =(7.5,7.5))
        plt.plot(100*(np.arange(len(self.average_rewards))+1), self.average_rewards)
        plt.axhline(y = -110, color = 'r', linestyle = '-')
        plt.title('Average reward over the past 100 simulations', fontsize = 10)
        plt.legend(['Q-learning performance','Benchmark'])
        plt.xlabel('Number of simulations', fontsize = 10)
        plt.ylabel('Average reward', fontsize = 10)

    def play_game(self):
        # Make eval env which renders when taking a step
        eval_env = gym.make(env_name, render_mode='human')
        state = eval_env.reset()[0]
        done=False
        # Run the environment for 1 episode
        while not done:
            state = self.discretize_state(state)
            action = np.argmax(self.Qtable[state[0],state[1],:])
            next_state, reward, terminated, truncated, info = eval_env.step(action)
            done = terminated or truncated
            state = next_state
        eval_env.close()

# %%
class TestEnv(Env):
    def __init__(self):
        self.action_space = Discrete(3) # 3 actions, go down, stay, go up

        self.observation_space = Box(low=np.array([0]), high=np.array([100])) # temperature range, 0 to 100
        self.state = 38 + random.randint(-3,3) # initial temperature fluctuation
        self.shower_length = 60 # 60 steps/seconds
    def step(self, action):
        self.state += action-1 # controlling how the action influences the state (here, temp movement on the temperature)
        self.shower_length -= 1

        done = False

        if self.state>=37 and self.state <=39:
            reward = 1
        else:
            reward = -1

        if self.shower_length <= 0:
            done = True

        self.state += random.randint(-1,1) # add random flucuations in each step

        info = {}

        return self.state, reward, done, info

    def render(self):
        pass

    def reset(self):
        self.state = 38 + random.randint(-3,3)
        self.shower_length = 60

        return self.state # return initial observation (=initial state)

# %%
env = TestEnv()
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
env.observation_space.sample()
# Out:
# array([83.77458], dtype=float32)

# %%
n_actions = 5
def get_action_space(n_actions):
  span = 50.0 / (n_actions - 1)
  actions = [ span * i - 25.0 for i in range(n_actions) ]
  print(f"actions: {actions}")
  return actions

action_space = get_action_space(n_actions=n_actions)
# Out:
# actions: [-25.0, -12.5, 0.0, 12.5, 25.0]

# %%
# Read the CSV file to get the samples
df_train_data = pd.read_csv("train_transformed.csv")
train_data = df_train_data.drop(columns=['PRICES'])
train_data.columns = [i for i in range(24)]
train_data = train_data.dropna()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-73-93c6d18a0ec7> in <cell line: 2>()
#       1 # Read the CSV file to get the samples
# ----> 2 df_train_data = pd.read_csv("train_transformed.csv")
#       3 train_data = df_train_data.drop(columns=['PRICES'])
#       4 train_data.columns = [i for i in range(24)]
#       5 train_data = train_data.dropna()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train_transformed.csv'

# %%
class TestEnv(Env):
    def __init__(self):
        self.action_space = Discrete(n_actions) # 5 actions, go down, stay, go up
        self.observation_space = Box(low=np.array([0]), high=np.array([50])) # temperature range, 0 to 100
        self.length = 24

        self.sample = train_data.sample()

        self.current_battery_level = np.random.randint(20, 50, size=1)[0]
        self.time = 0 # at the 8:00 - 9:00
        self.athome_hourly_space = np.zeros(24) # at home or not at this time
        for i in self.athome_hourly_space:
          if i >= 10:   # it is the index of the column (so 10 is 18 - 8)
            self.athome_hourly_space[i] = 1  # at home
        else:
          self.athome_hourly_space[i] = 0  # make it simple now (without account for the random choice)

        self.electric_price = self.sample[self.time]

        # might need to normalize *******
        self.state = [self.current_battery_level, self.electric_price, self.time, self.athome_hourly_space[self.time]]


    def step(self, action):
        # current_battery_level = action # require mapping from volume to action
        # check if it is night
        self.time += 1
        if self.time >= 10:
          self.athome = 1
        else:
          self.athome = 0

        electric_price = self.sample[self.time]  # get from data

        # check if >=50, and pick the action which is not large than 50 after summing up
        # if current_volume < 50:
        #   temp_action_space = copy.deepcopy(action_space)
        #   temp_action_space_1 = temp_action_space + current_volume - 50
        #   temp = temp_action_space_1[temp_action_space_1 >= 0]
        #   action = np.random.choice(temp, 1) + 20 - current_volume

        if self.athome == 1:
          current_battery_level += action_space[action] * 0.9
        else:
          current_battery_level -= current_battery_level - 2

        self.state = [current_battery_level, electric_price, time, self.athome_hourly_space[self.time]]



        # self.state += action-1 # controlling how the action influences the state (here, temp movement on the temperature)
        # self.state = [current_battery_level, electric_price, time, athome_hourly_space]
        # self.shower_length -= 1

        done = False

        if self.athome_hourly_space[self.time] == 1:
          if action > 0 :
            reward = -1 * action_space[action] * self.sample[self.time]
          else:
            reward = -1 * action_space[action] * self.sample[self.time] * 0.9
        else:
            reward = 0


        if self.time == 23:  # 7-8
        #     if current_volume < 20:
        #       temp_action_space = copy.deepcopy(action_space)
        #       temp_action_space_1 = temp_action_space + current_volume - 20
        #       temp = temp_action_space_1[temp_action_space_1 >= 0]
        #       action = np.random.choice(temp, 1) + 20 - current_volume

          done = True

        # self.state += random.randint(-1,1) # add random flucuations in each step

        info = {}

        return self.state, reward, done, info

    def render(self):
        pass
    def reset(self):
        self.sample = train_data.sample()
        current_battery_level = np.random.randint(20, 50, size=1)[0]
        self.time = 0 # at the 8:00
        self.athome_hourly_space = np.zeros(24) # at home or not at this time
        for i in self.athome_hourly_space:
          if i >= 10:   # it is the index of the column (so 10 is 18 - 8)
            self.athome_hourly_space[i] = 1  # at home
        else:
          self.athome_hourly_space[i] = 0  # make it simple now (without account for the random choice)

        self.state = [current_battery_level, self.sample[self.time], self.time, self.athome_hourly_space[self.time]]

        self.length = 24

        return self.state # return initial observation (=initial state)

# %%
episodes = 50
for episode in range(1, episodes):
    state = env.reset() # initial state
    done = False
    score = 0


    for hour, _ in enumerate(episode):


        action = env.action_space.sample() # sample random action
        new_state, reward, done, info = env.step(action)
        score += reward
    print(f"Episode {episode} has a total reward over 60 steps of: {score}")

# %%
os.chdir("../../Project")

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('AAPL.csv', sep=',', header=0)
# cols = pd.read_csv('AAPL.csv', nrows=1).columns
# df = pd.read_csv('AAPL.csv',sep=',"', usecols=cols)

df = df[["Date","Price", "Vol."]]#.iloc[:, [0, 4, 28, -2]]
df['Date'] = pd.to_datetime(df['Date'])
df["Vol."] = df["Vol."].apply(lambda x:float(x[:-1]))

df = df.sort_values(by=["Date"],ascending=True)
df = df.set_index('Date', drop=False)
df = df.rename(columns={"Vol.":"Vol"})

# for col in ['CAD', 'NZD', 'USD']:
#     df = df[df[col] != '-']
#     df[col] = pd.to_numeric(df[col])

# df = df[df['Date'] >= '2022-12-01'].reset_index(drop=True)
# print(df.head(3))
# print(f'\nThe date range: {df.Date.min()}/{ df.Date.max()}')

# plt.plot(df.index, [df['Price'], df["Vol"]])

plt.figure(figsize=(12,5))
plt.xlabel('Date')

ax1 = df.Price.plot(color='blue', grid=True, label='Price')
ax2 = df.Vol.plot(color='red', grid=True, secondary_y=True, label='Volume')

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()


plt.legend(h1+h2, l1+l2, loc=2)
plt.show()

# %%
s = np.random.normal(0, 0.1, 365)
s = np.sort(s)
plt.plot(s)

# %%
df[df["Date"]>]

# %%
plt.plot(year_df["Price"])

# %%
for i in df["Date"].dt.date:
    print(i)

# %%
df["Date"].dt.year

# %%
import datetime

year_range = range(2002,2025)

for year in year_range:
    year_half = datetime.date(year, 7, 1)
    year_df = df[df["Date"].dt.year == year]
    print(year_df)

    first_half_year_df = year_df[year_df["Date"].dt.date < year_half]
    second_half_year_df = year_df[year_df["Date"].dt.date <= year_half]

    #old
    year_length = len(year_df)
    year_mean = np.mean(year_df["Price"])
    year_variance = 0.2*year_mean

    year_gaussian_signal = np.random.normal(year_mean, year_variance, year_length)
    year_gaussian_signal = np.sort(year_gaussian_signal)
    # plt.plot(year_df["Price"]+year_gaussian_signal)

    #end old

    first_half_year_df["Price"] = first_half_year_df["Price"]*1.75
    second_half_year_df["Price"] = second_half_year_df["Price"]*0.5

    # add noise to first half of the current year
    df.loc[df["Date"].dt.year == 2003 and df["Date"].dt.date < year_half, "Price"] = first_half_year_df["Price"] #df["Date"].dt.year == 2003 +
    # add noise to second half of the current year
    df.loc[df["Date"].dt.year == 2003 and df["Date"].dt.date >= year_half, "Price"] = second_half_year_df["Price"]

    # i=0
    # for day in yearly_df["Date"].dt.date:
    #     if day < year_half:
    #         i+=1
    # print(i)

# %%
yearly_df

# %%
from datetime import timedelta
from mockseries.trend import LinearTrend
from mockseries.seasonality import SinusoidalSeasonality
from mockseries.noise import RedNoise
trend = LinearTrend(coefficient=2, time_unit=timedelta(days=4), flat_base=100)
seasonality = \
SinusoidalSeasonality(amplitude=20, period=timedelta(days=7)) \
+ SinusoidalSeasonality(amplitude=4, period=timedelta(days=1))
noise = RedNoise(mean=0, std=3, correlation=0.5)
timeseries = trend + seasonality + noise

seasonality.preview_week()
timeseries.preview_month()

# %%
np.mean(year_df["Price"])

# %%
datetime.date(year, 7, 1) > datetime.date(year, 7, 2)

# %%
import datetime as dt
year_range = range(1925,2025)

for year in year_range:
    yearly_df = df[df["Date"].dt.year == year]
    year_half = datetime.date(year, 7, 1)
    print(year_half)
    i=0
    for day in yearly_df["Date"].dt.date:
        if day < year_half:
            i+=1
    print(i)

# %%
from datetime import date, timedelta


sdate = date(2019,3,22)   # start date
edate = date(2019,4,9)
pd.date_range(sdate,edate-timedelta(days=1),freq='d')
